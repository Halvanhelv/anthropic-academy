# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
def add_user_message(messages, text):
    messages.append({"role": "user", "content": text})


def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }
    if system:
        params["system"] = system
    message = client.messages.create(**params)
    return message.content[0].text

# %%
prompt = "Write a Python function that checks a string for duplicate characters."

print("=== WITHOUT system prompt ===\n")
messages = []
add_user_message(messages, prompt)
answer = chat(messages)
print(answer)
# Out:
# === WITHOUT system prompt ===
# /var/folders/j9/c24102vj6459308yr9fkw4_h0000gn/T/ipykernel_55948/1929275420.py:13: DeprecationWarning: The model 'claude-sonnet-4-0' is deprecated and will reach end-of-life on June 15th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   message = client.messages.create(**params)
# Here are several Python functions to check for duplicate characters in a string:
#
# ## Method 1: Simple boolean check (most common use case)
#
# ```python
# def has_duplicates(s):
#     """
#     Check if a string contains duplicate characters.
#
#     Args:
#         s (str): The string to check
#
#     Returns:
#         bool: True if duplicates exist, False otherwise
#     """
#     return len(s) != len(set(s))
#
# # Example usage
# print(has_duplicates("hello"))     # True (l appears twice)
# print(has_duplicates("world"))     # True (l appears twice)
# print(has_duplicates("python"))    # True (y appears twice... wait, no - this is False)
# print(has_duplicates("abcdef"))    # False (no duplicates)
# ```
#
# ## Method 2: Case-insensitive version
#
# ```python
# def has_duplicates_ignore_case(s):
#     """
#     Check if a string contains duplicate characters (case-insensitive).
#
#     Args:
#         s (str): The string to check
#
#     Returns:
#         bool: True if duplicates exist, False otherwise
#     """
#     s_lower = s.lower()
#     return len(s_lower) != len(set(s_lower))
#
# # Example usage
# print(has_duplicates_ignore_case("Hello"))    # True (H and l, considering case)
# print(has_duplicates_ignore_case("World"))    # True (l appears twice)
# ```
#
# ## Method 3: Return duplicate characters
#
# ```python
# def find_duplicates(s):
#     """
#     Find all duplicate characters in a string.
#
#     Args:
#         s (str): The string to check
#
#     Returns:
#         set: Set of characters that appear more than once
#     """
#     seen = set()
#     duplicates = set()
#
#     for char in s:
#         if char in seen:
#             duplicates.add(char)
#         else:
#             seen.add(char)
#
#     return duplicates
#
# # Example usage
# print(find_duplicates("hello"))      # {'l'}
# print(find_duplicates("programming")) # {'r', 'g', 'm'}
# print(find_duplicates("abcdef"))     # set() (empty set)
# ```
#
# ## Method 4: Count occurrences of each character
#
# ```python
# def get_character_counts(s):
#     """
#     Get count of each character in the string.
#
#     Args:
#         s (str): The string to analyze
#
#     Returns:
#         dict: Dictionary with characters as keys and counts as values
#     """
#     char_count = {}
#
#     for char in s:
#         char_count[char] = char_count.get(char, 0) + 1
#
#     return char_count
#
# def has_duplicates_detailed(s):
#     """
#     Check for duplicates and return detailed information.
#
#     Args:
#         s (str): The string to check
#
#     Returns:
#         tuple: (has_duplicates: bool, character_counts: dict)
#     """
#     counts = get_character_counts(s)
#     has_dups = any(count > 1 for count in counts.values())
#
#     return has_dups, counts
#
# # Example usage
# has_dups, counts = has_duplicates_detailed("hello")
# print(f"Has duplicates: {has_dups}")  # True
# print(f"Character counts: {counts}")   # {'h': 1, 'e': 1, 'l': 2, 'o': 1}
# ```
#
# ## Method 5: Using Counter from collections
#
# ```python
# from collections import Counter
#
# def check_duplicates_counter(s):
#     """
#     Check for duplicates using Counter from collections module.
#
#     Args:
#         s (str): The string to check
#
#     Returns:
#         bool: True if duplicates exist, False otherwise
#     """
#     char_counts = Counter(s)
#     return any(count > 1 for count in char_counts.values())
#
# def get_duplicates_with_counts(s):
#     """
#     Get duplicate characters with their counts

# %%
print("\n=== WITH system prompt ===\n")
messages = []
add_user_message(messages, prompt)
answer = chat(messages, system="You are a Python engineer who writes very concise code")
print(answer)
# Out:
# === WITH system prompt ===
# /var/folders/j9/c24102vj6459308yr9fkw4_h0000gn/T/ipykernel_55948/1929275420.py:13: DeprecationWarning: The model 'claude-sonnet-4-0' is deprecated and will reach end-of-life on June 15th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   message = client.messages.create(**params)
# ```python
# def has_duplicates(s):
#     return len(s) != len(set(s))
# ```
#
# This function converts the string to a set (which removes duplicates) and compares lengths. If they differ, duplicates exist.
#
# Example usage:
# ```python
# has_duplicates("hello")    # True (duplicate 'l')
# has_duplicates("world")    # True (duplicate 'r')
# has_duplicates("python")   # False (no duplicates)
# ```
